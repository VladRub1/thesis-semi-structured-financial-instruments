# %% [markdown]
# # EIS Collection Analysis
#
# Load collected Parquet tables from `data/processed/` and summarize the
# attachments and attribute coverage.

# %%
from pathlib import Path
import re
import pandas as pd


def resolve_processed_base() -> Path:
    cwd = Path.cwd().resolve()
    candidates = [
        cwd / "data" / "processed",
        cwd / "processed",
    ]
    for parent in [cwd, *cwd.parents]:
        candidates.append(parent / "data" / "processed")
    for candidate in candidates:
        if candidate.exists():
            return candidate
    raise FileNotFoundError("Could not locate data/processed directory from cwd")


def extract_run_id(path: Path) -> int | None:
    match = re.search(r"run_(\d+)_", path.name)
    if not match:
        return None
    return int(match.group(1))


def latest_run_id(path: Path) -> int | None:
    run_ids = [extract_run_id(p) for p in path.glob("*.parquet")]
    run_ids = [rid for rid in run_ids if rid is not None]
    return max(run_ids) if run_ids else None


def read_run_parquets(path: Path, run_id: int | None) -> pd.DataFrame:
    if run_id is None:
        files = list(path.glob("*.parquet"))
    else:
        files = list(path.glob(f"*run_{run_id}_*.parquet"))
    if not files:
        return pd.DataFrame()
    frames = [pd.read_parquet(file) for file in sorted(files)]
    return pd.concat(frames, ignore_index=True)


base = resolve_processed_base()
print("Using processed base:", base)

run_id = latest_run_id(base / "guarantees")
print("Latest run_id:", run_id)

guarantees = read_run_parquets(base / "guarantees", run_id)
attributes = read_run_parquets(base / "attributes", run_id)
files = read_run_parquets(base / "files", run_id)

print("guarantees rows", len(guarantees))
print("attributes rows", len(attributes))
print("files rows", len(files))

display(guarantees.head())
display(attributes.head())
display(files.head())
# Out:
# Using processed base: /Users/home/Work/10-edu/data-science/thesis/code/masters-thesis-dev/data/processed
# Latest run_id: 53
# guarantees rows 9893
# attributes rows 497427
# files rows 10378
#    run_id       id status                                        general_url  \
# 0      53  1691322     OK  https://zakupki.gov.ru/epz/bankguarantee/guara...
# 1      53  1699189     OK  https://zakupki.gov.ru/epz/bankguarantee/guara...
# 2      53  1699068     OK  https://zakupki.gov.ru/epz/bankguarantee/guara...
# 3      53  1698670     OK  https://zakupki.gov.ru/epz/bankguarantee/guara...
# 4      53  1699847     OK  https://zakupki.gov.ru/epz/bankguarantee/guara...
#
#                                        documents_url  \
# 0  https://zakupki.gov.ru/epz/bankguarantee/guara...
# 1  https://zakupki.gov.ru/epz/bankguarantee/guara...
# 2  https://zakupki.gov.ru/epz/bankguarantee/guara...
# 3  https://zakupki.gov.ru/epz/bankguarantee/guara...
# 4  https://zakupki.gov.ru/epz/bankguarantee/guara...
#
#                          fetched_at warnings error
# 0  2026-02-13T07:34:35.285531+00:00       []
# 1  2026-02-13T07:34:45.146331+00:00       []
# 2  2026-02-13T07:34:53.677027+00:00       []
# 3  2026-02-13T07:35:03.546578+00:00       []
# 4  2026-02-13T07:35:13.711238+00:00       []
#    run_id       id                            section  \
# 0      53  1691322  Сводная информация (верхний блок)
# 1      53  1691322  Сводная информация (верхний блок)
# 2      53  1691322  Сводная информация (верхний блок)
# 3      53  1691322  Сводная информация (верхний блок)
# 4      53  1691322  Сводная информация (верхний блок)
#
#                                  field_name  \
# 0                                    Статус
# 1                               Банк-гарант
# 2                                       ИНН
# 3                                       КПП
# 4  Номер извещения об осуществлении закупки
#
#                                          field_value  document_index  \
# 0                                          Размещено             NaN
# 1  "АКЦИОНЕРНЫЙ КОММЕРЧЕСКИЙ БАНК "ДЕРЖАВА" ПУБЛИ...             NaN
# 2                                         7729003482             NaN
# 3                                          770401001             NaN
# 4                                0172200003118000032             NaN
#
#   document_number
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#    run_id       id  file_index stored_filename  \
# 0      53  1691322           1   1691322_1.pdf
# 1      53  1699189           1   1699189_1.pdf
# 2      53  1699068           1   1699068_1.pdf
# 3      53  1698670           1   1698670_1.pdf
# 4      53  1699847           1   1699847_1.pdf
#
#                                          stored_path  \
# 0  /Users/home/Work/10-edu/data-science/thesis/co...
# 1  /Users/home/Work/10-edu/data-science/thesis/co...
# 2  /Users/home/Work/10-edu/data-science/thesis/co...
# 3  /Users/home/Work/10-edu/data-science/thesis/co...
# 4  /Users/home/Work/10-edu/data-science/thesis/co...
#
#            original_filename  \
# 0                 186165.pdf
# 1                БГ_5120.pdf
# 2    лига групп 15732-21.pdf
# 3                  41486.pdf
# 4  БГ 4875 от 20.02.2018.pdf
#
#                                         download_url  document_index  \
# 0  https://zakupki.gov.ru/44fz/filestore/public/1...               1
# 1  https://zakupki.gov.ru/44fz/filestore/public/1...               1
# 2  https://zakupki.gov.ru/44fz/filestore/public/1...               1
# 3  https://zakupki.gov.ru/44fz/filestore/public/1...               1
# 4  https://zakupki.gov.ru/44fz/filestore/public/1...               1
#
#           document_number  page_count        mime_type download_status  \
# 0  0B62783200007618000401           2  application/pdf      DOWNLOADED
# 1  01T2380802757718000101           2  application/pdf      DOWNLOADED
# 2  0J11910300307018001001           2  application/pdf      DOWNLOADED
# 3  04R3471002615218000101           2  application/pdf      DOWNLOADED
# 4  0381370267767018000501           2  application/pdf      DOWNLOADED
#
#                                               sha256
# 0  ac42cdb358e368da3dd590e677bde7b9d7768bcb7eec27...
# 1  d2f1e333ab0463eda901fcbc064dd2502b11df95282462...
# 2  f83dfc9cd218d6001c99ef4cc657a4fda1ece3be32f5a0...
# 3  824928a33dc4471d8f293fb6f58b5849e7d79f5f31546e...
# 4  524f077e7c96e37ffb61bdbe3478f7a1be62586455c3fd...

# %%
# summary for the last run
if files.empty:
    print("No files table found.")
else:
    files = files.copy()
    files["extension"] = files["stored_filename"].str.extract(r"(\.[^\.]+)$", expand=False).fillna("")

    def file_size(path: str) -> int:
        try:
            return Path(path).stat().st_size
        except FileNotFoundError:
            return 0
        except OSError:
            return 0

    files["size_bytes"] = files["stored_path"].apply(file_size)

    print("Download status counts")
    display(files["download_status"].value_counts())

    print("File extensions")
    display(files["extension"].value_counts())

    total_size = int(files["size_bytes"].sum())
    downloaded_size = int(files.loc[files["download_status"].eq("DOWNLOADED"), "size_bytes"].sum())

    print("Total size (bytes)", total_size)
    print("Downloaded size (bytes)", downloaded_size)
    print("Existing files", int((files["size_bytes"] > 0).sum()))

    if "sha256" in files.columns:
        nonempty = files[files["sha256"].astype(str).str.len() > 0]
        dupes = nonempty[nonempty.duplicated("sha256", keep=False)]
        if dupes.empty:
            print("No duplicate hashes detected.")
        else:
            print("Duplicate hashes detected")
            display(dupes.sort_values("sha256"))
# Out:
# Download status counts
# download_status
# DOWNLOADED    20
# Name: count, dtype: int64
# File extensions
# extension
# .pdf    20
# Name: count, dtype: int64
# Total size (bytes) 35095657
# Downloaded size (bytes) 35095657
# Existing files 20
# Duplicate hashes detected
#     run_id       id  file_index stored_filename  \
# 7       38  1940011           1   1940011_1.pdf
# 8       38  1940011           2   1940011_2.pdf
# 10      38  1962721           1   1962721_1.pdf
# 11      38  1962721           2   1962721_2.pdf
#
#                                           stored_path  \
# 7   /Users/home/Work/10-edu/data-science/thesis/co...
# 8   /Users/home/Work/10-edu/data-science/thesis/co...
# 10  /Users/home/Work/10-edu/data-science/thesis/co...
# 11  /Users/home/Work/10-edu/data-science/thesis/co...
#
#                      original_filename  \
# 7    БГ 65865 ВБЦ-18 от 21.06.2018.pdf
# 8    БГ 65865 ВБЦ-18 от 21.06.2018.pdf
# 10  Бланк_гар_ПСФ Корт_2216_290618.pdf
# 11  Бланк_гар_ПСФ Корт_2216_290618.pdf
#
#                                          download_url  document_index  \
# 7   https://zakupki.gov.ru/44fz/filestore/public/1...               1
# 8   https://zakupki.gov.ru/44fz/filestore/public/1...               2
# 10  https://zakupki.gov.ru/44fz/filestore/public/1...               1
# 11  https://zakupki.gov.ru/44fz/filestore/public/1...               2
#
#            document_number  page_count        mime_type download_status  \
# 7   0383711300305118000603           2  application/pdf      DOWNLOADED
# 8   0383711300305118000601           2  application/pdf      DOWNLOADED
# 10  02L3781703211518002303           2  application/pdf      DOWNLOADED
# 11  02L3781703211518002301           2  application/pdf      DOWNLOADED
#
#                                                sha256 extension  size_bytes
# 7   ae77565070884034178385680ed4ae896e1e1ad54d099b...      .pdf     2344371
# 8   ae77565070884034178385680ed4ae896e1e1ad54d099b...      .pdf     2344371
# 10  bd7f1e44901be948bd28433c919095ea5613d82d26a708...      .pdf     1994414
# 11  bd7f1e44901be948bd28433c919095ea5613d82d26a708...      .pdf     1994414

# %%
# attributes['field_name'].value_counts()

# %%
# guarantees.head()

# %%
from pathlib import Path
import hashlib


def read_all_parquets(path: Path) -> pd.DataFrame:
    files = list(path.glob("*.parquet"))
    if not files:
        return pd.DataFrame()
    frames = [pd.read_parquet(file) for file in sorted(files)]
    return pd.concat(frames, ignore_index=True)


guarantees_all = read_all_parquets(base / "guarantees")
attributes_all = read_all_parquets(base / "attributes")
files_all = read_all_parquets(base / "files")

if guarantees_all.empty:
    raise RuntimeError("No guarantees tables found in processed folder.")

if "run_id" not in guarantees_all.columns:
    raise RuntimeError("guarantees table missing run_id; rerun parser with run_id support.")

# Pick the latest run per guarantee ID.
guarantees_latest = (
    guarantees_all.sort_values(["id", "run_id", "fetched_at"]).drop_duplicates("id", keep="last")
)

latest_keys = guarantees_latest[["id", "run_id"]].drop_duplicates()
attributes_latest = attributes_all.merge(latest_keys, on=["id", "run_id"], how="inner")
files_latest = files_all.merge(latest_keys, on=["id", "run_id"], how="inner")


def file_exists(path_value: str) -> bool:
    if not isinstance(path_value, str) or not path_value:
        return False
    return Path(path_value).exists()


files_latest["file_exists"] = files_latest["stored_path"].apply(file_exists)
files_latest_existing = files_latest[files_latest["file_exists"]].copy()

print("Latest guarantees rows", len(guarantees_latest))
print("Latest attributes rows", len(attributes_latest))
print("Latest files rows", len(files_latest))
print("Existing files rows", len(files_latest_existing))
# Out:
# Latest guarantees rows 358238
# Latest attributes rows 17708395
# Latest files rows 373051
# Existing files rows 371963

# %%
# these files doesn't exist
files_latest[files_latest['file_exists'] == False]
# Out:
#            id  file_index stored_filename  \
# 48     461122           1    461122_1.pdf
# 69     119178           1
# 132     40710           2
# 861        15           1
# 880        66           2
# ...       ...         ...             ...
# 33333    9717           3
# 33334    9835           1
# 33337    9902           3
# 33349    9821           3
# 33353    9821           7
#
#                                              stored_path  \
# 48     /Users/home/Work/10-edu/data-science/thesis/co...
# 69
# 132
# 861
# 880
# ...                                                  ...
# 33333
# 33334
# 33337
# 33349
# 33353
#
#                  original_filename  \
# 48          11122015193909_002.pdf
# 69                        1941.pdf
# 132          Договор БГ 385-53.pdf
# 861     БГ 018 (01814, 15 млн).jpg
# 880             гарантия 14103.pdf
# ...                            ...
# 33333  doc08297020140326154708.pdf
# 33334           ООО Мистстудия.pdf
# 33337                     ДС 2.tif
# 33349       Заявка уралтранс 1.pdf
# 33353       Заявка уралтранс 1.pdf
#
#                                             download_url mime_type  \
# 48     https://zakupki.gov.ru/44fz/filestore/public/1...
# 69     https://zakupki.gov.ru/44fz/filestore/public/1...
# 132    https://zakupki.gov.ru/44fz/filestore/public/1...
# 861    https://zakupki.gov.ru/44fz/filestore/public/1...
# 880    https://zakupki.gov.ru/44fz/filestore/public/1...
# ...                                                  ...       ...
# 33333  https://zakupki.gov.ru/44fz/filestore/public/1...
# 33334  https://zakupki.gov.ru/44fz/filestore/public/1...
# 33337  https://zakupki.gov.ru/44fz/filestore/public/1...
# 33349  https://zakupki.gov.ru/44fz/filestore/public/1...
# 33353  https://zakupki.gov.ru/44fz/filestore/public/1...
#
#         download_status sha256  document_index         document_number  \
# 48       FAILED_TIMEOUT                    1.0  01Q2772339668515000501
# 69     FAILED_NOT_FOUND                    1.0  0420173200004614004101
# 132    FAILED_NOT_FOUND                    1.0  05A0141200001514000603
# 861    FAILED_NOT_FOUND                    1.0  0930373100042414000101
# 880    FAILED_NOT_FOUND                    2.0  0890373200001614000101
# ...                 ...    ...             ...                     ...
# 33333  FAILED_NOT_FOUND                    1.0  0420127200001114000101
# 33334  FAILED_NOT_FOUND                    1.0  02H0148300022214000301
# 33337  FAILED_NOT_FOUND                    1.0  07X0315300000114001401
# 33349  FAILED_NOT_FOUND                    1.0  00P0372200180814000205
# 33353  FAILED_NOT_FOUND                    2.0  00P0372200180814000201
#
#        page_count  run_id  file_exists
# 48            0.0     NaN        False
# 69            0.0    14.0        False
# 132           0.0    17.0        False
# 861           0.0    28.0        False
# 880           0.0    28.0        False
# ...           ...     ...          ...
# 33333         0.0    35.0        False
# 33334         0.0    35.0        False
# 33337         0.0    35.0        False
# 33349         0.0    35.0        False
# 33353         0.0    35.0        False
#
# [1088 rows x 14 columns]

# %%
# sample
files_latest_existing[files_latest_existing['id'] == 40710]
# Out:
#         id  file_index stored_filename  \
# 131  40710           1     40710_1.pdf
# 133  40710           3     40710_3.pdf
#
#                                            stored_path      original_filename  \
# 131  /Users/home/Work/10-edu/data-science/thesis/co...  Договор БГ 385-53.pdf
# 133  /Users/home/Work/10-edu/data-science/thesis/co...  Договор БГ 385-53.pdf
#
#                                           download_url        mime_type  \
# 131  https://zakupki.gov.ru/44fz/filestore/public/1...  application/pdf
# 133  https://zakupki.gov.ru/44fz/filestore/public/1...  application/pdf
#
#     download_status                                             sha256  \
# 131      DOWNLOADED  e829cda7956f706ea1424c8cd784bf0ea94906553a1708...
# 133      DOWNLOADED  e829cda7956f706ea1424c8cd784bf0ea94906553a1708...
#
#      document_index         document_number  page_count  run_id  file_exists
# 131             1.0  05A0141200001514000603         3.0    17.0         True
# 133             2.0  05A0141200001514000601         3.0    17.0         True

# %%
final_dir = base / "final"
final_dir.mkdir(parents=True, exist_ok=True)

guarantees_latest.to_csv(final_dir / "guarantees_latest.csv", index=False)
attributes_latest.to_csv(final_dir / "attributes_latest.csv", index=False)
files_latest_existing.to_csv(final_dir / "files_latest.csv", index=False)

print("Saved CSVs to", final_dir)
# Out:
# Saved CSVs to /Users/home/Work/10-edu/data-science/thesis/code/masters-thesis-dev/data/processed/final

# %%
def compute_sha256(path: Path) -> str:
    hasher = hashlib.sha256()
    with path.open("rb") as handle:
        for chunk in iter(lambda: handle.read(1024 * 1024), b""):
            hasher.update(chunk)
    return hasher.hexdigest()


total_files = len(files_latest_existing)
sha_series = files_latest_existing.get("sha256")
if sha_series is None:
    sha_series = pd.Series([""] * total_files)

sha_series = sha_series.fillna("")
missing_sha = files_latest_existing[sha_series.eq("")]

if not missing_sha.empty:
    computed = []
    for path_value in missing_sha["stored_path"]:
        try:
            computed.append(compute_sha256(Path(path_value)))
        except Exception:
            computed.append("")
    sha_series.loc[missing_sha.index] = computed

unique_files = sha_series[sha_series.ne("")].nunique()

print("Total downloaded files (existing):", total_files)
print("Unique files by sha256:", unique_files)
# Out:
# Total downloaded files (existing): 279685
# Unique files by sha256: 253594

# %%
# files_latest_existing[files_latest_existing['stored_filename'].str.endswith(".jpg")]

# %%
# files_latest_existing[files_latest_existing['stored_filename'].str.endswith(".doc")].head()

# %% [markdown]
# ### Draw random samples

# %%
import numpy as np
np.random.seed(13)
print(np.random.choice(list(range(1, 1962721)), 10), sep=',')
# Out:
# [1540435 1751217 1015883  253457  256743 1737571 1791733 1900698 1860333
#  1216443]

# %%
import random

# Generate 25 random integers between 1 and 2000000
random_numbers = [str(random.randint(1, 1962721)) for _ in range(1000)]

# Print as a comma-separated string
print(",".join(random_numbers))
# Out:
# 632799,1855251,427914,134076,771734,1252185,927954,182960,647662,791601,1527702,165346,330910,1406207,920364,22646,517826,760564,1604391,680228,408552,1791999,1006478,280453,1705872,1485846,1343216,1757698,1221434,23371,471740,848061,1918047,1712632,1907802,89205,1478783,131467,1733332,1835254,1835257,574568,902023,799717,962972,785436,1896702,1504393,837180,1514219,14599,1048194,962218,1884024,111279,1206503,324864,1948850,141638,1227861,1711964,1810707,1252730,469093,125763,674026,1829334,590980,1096111,814434,1863851,94598,694723,982556,666999,1244657,23927,359014,296830,1555730,1394269,1349052,472611,816536,1323696,134057,403195,1033882,1496067,533237,610329,710262,287553,1097956,3867,1158704,673804,1543957,1844381,1491166,650777,1899724,1571107,1698717,498192,200543,282113,688238,552192,1512231,311273,558256,1545165,36860,1716103,908737,1827992,1032447,824100,889860,272652,1305664,1498141,588969,625657,171545,823671,1173043,195180,1234197,602460,1556709,943796,915101,837800,415493,801847,644485,888883,1474890,279989,363411,532055,724023,546257,1162700,2511,561343,1522100,1906784,1175004,133541,1074815,1633183,332542,1881650,980568,1393324,761710,1613010,298852,392968,184228,859203,476380,370264,1827171,1346838,974927,1425119,969274,562847,114333,938692,77556,1723524,192770,885841,280744,1526996,1223168,207311,1871422,33536,1701034,490483,403443,1391807,1512526,221510,461128,1411086,1117217,1040787,1298159,913437,1031616,7386,396872,408788,133665,1205819,1189007,1767912,328584,1900257,1288989,1493817,1655277,1320353,1663184,1657371,241328,1527327,311350,743991,474292,1633192,965354,771409,1680922,464820,1824926,1295762,1164085,948039,666290,1814448,945304,1059143,1676999,260103,47579,664613,849877,442693,825365,253643,392308,607460,1262420,797280,262176,1524260,829764,127779,174956,456313,520257,1432644,1957882,27957,1843651,856869,1423425,192975,639715,1050550,818936,1776917,1067533,1176834,10546,936640,1500590,18870,352448,387640,34682,1316560,613583,479712,1681533,1091959,1631252,1465527,61719,516717,877507,877443,1174267,113264,1184575,1453152,1730268,637002,1562172,1490670,593624,1957780,1039990,1135587,1405934,1773088,95908,1866787,1892476,1741237,684774,839870,1362587,743913,904834,1439105,1752156,1641454,1501379,912058,496599,470733,460368,212995,466832,1481887,539341,1282465,670101,1375436,1157589,575915,524220,1644669,1104064,1332949,1764994,1626120,837452,659078,1355937,1762292,1666557,292396,1835930,1791709,1380101,975454,1767461,1824554,130820,668392,821095,1820295,708586,78871,1222454,1243272,9891,1916923,1802325,293132,1001641,1211815,1473892,691166,1592519,514319,254060,1802958,189884,1496641,1632321,1414665,1891239,294452,1558001,1590194,63646,4898,930015,1086950,1139320,1723900,137227,977916,1094400,1500576,1111016,277386,663467,990041,302778,1491312,1664008,1494244,1499877,552461,821141,1725287,1268701,884495,1538965,1853417,101142,432880,497615,1623501,303781,1826642,686401,945321,1085400,83029,229217,1528838,408041,687408,1107147,237896,1119825,1326354,1218308,510768,1207830,158567,501770,97041,1008450,1563111,1666823,544856,506751,136751,533190,465911,623040,188402,1556059,1699439,643351,690329,1958403,154364,1870318,1485706,1410370,869627,361283,273846,309358,674275,458824,379123,1734657,1417357,1559639,412750,1512657,398438,883047,51536,966134,1735739,1433849,63655,264975,562257,558701,1771481,446993,1798328,1301106,1383786,353251,936095,814702,1381771,858609,178286,1247238,1443685,893303,927268,536145,1479309,1849565,837112,1111932,1357049,208511,897222,1151811,77993,1119360,404929,604025,1365951,1788479,361009,27640,972858,1212637,1056576,815077,1590341,752982,1672229,1187017,1777574,238713,961683,1767283,673042,175157,1436827,1570348,111549,1554696,1851116,753884,1559022,940420,570051,163932,927027,384787,1003204,827481,1771260,322458,1462465,648703,508797,859146,1125551,474832,1682386,622758,654547,899605,292173,1078084,1582906,939681,185167,1099130,616331,1381254,1162263,997813,393641,189202,16 ...
